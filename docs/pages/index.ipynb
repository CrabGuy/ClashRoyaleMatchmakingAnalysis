# %% [markdown]
# # Main explanation
#
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/your-username/clash-royale-matchmaking/blob/main/pages/full_analysis.ipynb)
#
# This is the main thing people will see and it should have all of the
# findings of the analysis
